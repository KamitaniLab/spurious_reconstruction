# %%
import os
import sys

import json
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd
import sys
sys.path.append('./nsd_access/')
from nsd_access import NSDAccess

# %%
nsd_base_path = '/home/nu/data/fmri_shared/public/NSD/latest/'
coco_json_path = "/home/nu/data/fmri_shared/public/NSD/latest/nsddata_stimuli/stimuli/nsd/annotations/captions_train2017.json"
# Settings -------------------------------------------------------------------
nsda = NSDAccess(nsd_base_path)

# load json filw
with open(coco_json_path, 'r') as f:
    dl = json.load(f)

# %%
true_image_dir = '/home/nu/data/contents_shared/NSD-stimuli/source/'
true_image_ext = 'png'
true_image_all = list(np.sort((glob(os.path.join(true_image_dir, '*.' + true_image_ext)))))

# %%
recon_images_fig_02 =  ['nsd03050', 'nsd03435', 'nsd05302', 'nsd07008', 'nsd10065', 'nsd22264',#'nsd13721',
                    'nsd37802' , 'nsd19201', 'nsd26436',  'nsd10007',  'nsd21509',  'nsd67803'
                   ]
post_hoc_selection_images_fig_03 = ["nsd57479", "nsd38854",  "nsd56043", "nsd43501", ]


similar_image_fig_04 = ["nsd45007", "nsd58303", "nsd12196", "nsd00086", "nsd64709",
                "nsd26668", "nsd61882", "nsd52180", "nsd05238", "nsd16088", 
                "nsd68298", "nsd00564", "nsd65571", "nsd04132", "nsd03183",
                 "nsd65410", "nsd66330", "nsd41334", "nsd29197", "nsd30480"
                ]

true_feat_recon_images_fig_10 = ['nsd32308']




selected_images = recon_images_fig_02 + post_hoc_selection_images_fig_03 + similar_image_fig_04 +true_feat_recon_images_fig_10
#selected_images = post_hoc_selection_images
true_images = [true_image for true_image in true_image_all  if os.path.basename(true_image).split('.')[0] in selected_images]
print(len(true_images))
# Out:
# 37

# %%
dl['licenses']
# Out:
# [{'url': 'http://creativecommons.org/licenses/by-nc-sa/2.0/',
#   'id': 1,
#   'name': 'Attribution-NonCommercial-ShareAlike License'},
#  {'url': 'http://creativecommons.org/licenses/by-nc/2.0/',
#   'id': 2,
#   'name': 'Attribution-NonCommercial License'},
#  {'url': 'http://creativecommons.org/licenses/by-nc-nd/2.0/',
#   'id': 3,
#   'name': 'Attribution-NonCommercial-NoDerivs License'},
#  {'url': 'http://creativecommons.org/licenses/by/2.0/',
#   'id': 4,
#   'name': 'Attribution License'},
#  {'url': 'http://creativecommons.org/licenses/by-sa/2.0/',
#   'id': 5,
#   'name': 'Attribution-ShareAlike License'},
#  {'url': 'http://creativecommons.org/licenses/by-nd/2.0/',
#   'id': 6,
#   'name': 'Attribution-NoDerivs License'},
#  {'url': 'http://flickr.com/commons/usage/',
#   'id': 7,
#   'name': 'No known copyright restrictions'},
#  {'url': 'http://www.usa.gov/copyright.shtml',
#   'id': 8,
#   'name': 'United States Government Work'}]

# %%
# Out:
# [{'license': 3,
#   'file_name': '000000391895.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000391895.jpg',
#   'height': 360,
#   'width': 640,
#   'date_captured': '2013-11-14 11:18:45',
#   'flickr_url': 'http://farm9.staticflickr.com/8186/8119368305_4e622c8349_z.jpg',
#   'id': 391895},
#  {'license': 4,
#   'file_name': '000000522418.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000522418.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 11:38:44',
#   'flickr_url': 'http://farm1.staticflickr.com/1/127244861_ab0c0381e7_z.jpg',
#   'id': 522418},
#  {'license': 3,
#   'file_name': '000000184613.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000184613.jpg',
#   'height': 336,
#   'width': 500,
#   'date_captured': '2013-11-14 12:36:29',
#   'flickr_url': 'http://farm3.staticflickr.com/2169/2118578392_1193aa04a0_z.jpg',
#   'id': 184613},
#  {'license': 3,
#   'file_name': '000000318219.jpg',
# ...
